# %%
# Importing Libraries
import selenium
import csv
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementClickInterceptedException

#Importing requests
import requests
from selenium.webdriver.common.by import By
# importing regex
import re

import time
import random

# %%
driver = webdriver.Chrome()

# %%
url_1="https://www.fabindia.com/shop/women-products"

# %%
driver.get(url_1)

# %%
scroll_times = 30

# Scroll n times with a 2-second delay after each scroll
for _ in range(scroll_times):
    # Scroll down using JavaScript
    driver.execute_script("window.scrollBy(0, 8*500);")
    
    # Wait for 2 seconds
    time.sleep(2)

# %%
# Find all <div> elements with classes "col-6", "col-sm-6", and "col-md-3"
product_items = driver.find_elements(By.CSS_SELECTOR, "div.custom-prod-desc")

i=0
# Iterate through each <div> element
for item in product_items:
    # Find the <a> element within the <div> with the specified class
    product_link = item.find_element(By.CSS_SELECTOR, 'a.text-decoration-none.text-muted.text-secondary')

    # Extract the relative URL from the href attribute
    relative_url = product_link.get_attribute("href")

    # Construct the absolute URL by appending the relative URL to the base URL
    absolute_url = relative_url
    print(absolute_url)
    i=i+1
print(i)
# Out:
# https://www.fabindia.com/natural-cotton-woven-stole-20165295
# https://www.fabindia.com/offwhite-jute-tote-20164833
# https://www.fabindia.com/natural-cotton-printed-dupatta-20165200
# https://www.fabindia.com/natural-cotton-printed-dupatta-20165199
# https://www.fabindia.com/natural-cotton-silk-printed-dupatta-20165184
# https://www.fabindia.com/green-jute-tote-20164788
# https://www.fabindia.com/silver-two-tone-dangler-earrings-20160746
# https://www.fabindia.com/mustard-silk-printed-stole-20155311
# https://www.fabindia.com/teal-silk-printed-stole-20166185
# https://www.fabindia.com/black-silk-printed-stole-20166187
# https://www.fabindia.com/orange-silk-printed-stole-20155260
# https://www.fabindia.com/mustard-silk-printed-stole-20166186
# https://www.fabindia.com/grey-silk-printed-stole-20166184
# https://www.fabindia.com/pink-cotton-silk-blend-batik-stole-20155238
# https://www.fabindia.com/green-cotton-silk-blend-batik-stole-20155237
# ...

# %%
import csv

# Open a CSV file in write mode
with open('FabIndia_WoMen.csv', 'w', newline='', encoding='utf-8') as csvfile:
    # Create a CSV writer object
    csv_writer = csv.writer(csvfile)
    
    # Write the header row
    csv_writer.writerow(['Sno','Brandname','Category','link','ProductType','ProductName','ProductCode','price','color1','color2','color3','color4','WearType','MaterialType','reviews','size1','Size2','size3','Size4','size5','size6','CountryOfOrigin','ReturnTime','Occasion'])
    

    # Find all <li> elements with class "product-item"
    product_items = driver.find_elements(By.CSS_SELECTOR, 'div.custom-prod-desc')
    
    # Initialize Sno counter
    sno = 1
    


    # Iterate through each <li> element
    for item in product_items:
        # Find the <a> element within the <li> with the specified href
        product_link = item.find_element(By.CSS_SELECTOR, 'a.text-decoration-none.text-muted.text-secondary')

        # Extract the relative URL from the href attribute
        relative_url = product_link.get_attribute("href")

        # Construct the absolute URL by appending the relative URL to the base URL
        absolute_url = relative_url

        driver.execute_script("window.open('{}', '_blank');".format(absolute_url))

        # Switch to the new tab
         # Wait for the page to load
        time.sleep(0.5)  # Adjust this delay if needed
        driver.switch_to.window(driver.window_handles[-1])
        # Find the <h1> element with the specified class


        # Find the product product_name
        driver.switch_to.window(driver.window_handles[-1])

        


        try:
            product_name_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-product-intro/div/h1')
            
            product_name = product_name_element.text.strip().replace('\n', ' ')
        except NoSuchElementException:
            product_name = "NA"

        # Find the product_price
        try:
            product_price_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-pdp-summary/div/div[2]')
            product_price = product_price_element.text.strip().replace('\n', ' ')
        except NoSuchElementException:
            product_price = "NA"

        #   #click desc
        # driver.switch_to.window(driver.window_handles[-1])
        # try:
        #     search_1 = driver.find_element(By.XPATH,'//*[@id="accordion"]/div/h2[1]')      
        #     search_1.click()
        # except NoSuchElementException:
        #     print("Element not found or unable to click. Continuing...")
        # except ElementClickInterceptedException:
        #     print("Element found but unable to click. Continuing...")

        # Find the product product_type
        try:
            product_type_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/div[4]/div/cx-page-slot/app-fab-bread-crumb/nav/a[4]')
            product_type = product_type_element.text.strip().replace('\n', ' ')
        except NoSuchElementException:
            product_type = "NA"

        # Find the MaterialType
        try:
            MaterialType_element = driver.find_element(By.XPATH, '//*[@id="flush-collapseOne"]/div/cx-product-attributes/div/div/table/tr[2]/td[3]/ul/li')
            MaterialType = MaterialType_element.text.strip().replace('\n', ' ')
        except NoSuchElementException:
            MaterialType = "NA"

        # Find the color1

                    
        try:
            color1_element = driver.find_element(By.XPATH, '//*[@id="sizes-pills-tabContent"]/div/div/div/div[2]/img[1]')
            color1 = color1_element.get_attribute("title").strip().replace('\n', ' ')
        except NoSuchElementException:
            color1 = "NA"
        

        # Find the color2

        try:
            color1_element = driver.find_element(By.XPATH, '//*[@id="sizes-pills-tabContent"]/div/div/div/div[2]/img[2]')
            color1 = color1_element.get_attribute("title").strip().replace('\n', ' ')
        except NoSuchElementException:
            color2 = "NA"


        try:
            color1_element = driver.find_element(By.XPATH, '//*[@id="sizes-pills-tabContent"]/div/div/div/div[2]/img[3]')
            color1 = color1_element.get_attribute("title").strip().replace('\n', ' ')
        except NoSuchElementException:
            color3 = "NA"


         
        # Find the color4

        try:
            color1_element = driver.find_element(By.XPATH, '//*[@id="sizes-pills-tabContent"]/div/div/div/div[2]/img[4]')
            color1 = color1_element.get_attribute("title").strip().replace('\n', ' ')
        except NoSuchElementException:
            color4 = "NA"


        driver.switch_to.window(driver.window_handles[-1])

        #    #click delv
        # try:
        #     search_1 = driver.find_element(By.XPATH,'//*[@id="accordion"]/div/h2[4]')      
        #     search_1.click()
        # except NoSuchElementException:
        #     print("Element not found or unable to click. Continuing...")
        # except ElementClickInterceptedException:
        #     print("Element found but unable to click. Continuing...")
      

        # Find the product_code
        try:
            product_code_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-product-intro/div/p')
            product_code = product_code_element.text.strip().replace('\n', ' ')
        except NoSuchElementException:
            product_code = "NA"


        # Find the CountryOfOrigin
        try:
            # CountryOfOrigin_element = driver.find_element(By.XPATH, '//*[@id="productDeclaration"]/div/ul/li[5]/span')
            # CountryOfOrigin = CountryOfOrigin_element.text.strip().replace('\n', ' ')
            CountryOfOrigin = "India"
        except NoSuchElementException:
            CountryOfOrigin = "India"

        # Find the Size1

        try:
            Size1_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-product-variants-container/div/app-fab-variant-size-selector/div/div[3]/div[1]/button')
            if Size1_element.is_enabled():
                Size1 = Size1_element.text.strip().replace('\n', ' ')
            else:
                Size1 = "NA"
        except NoSuchElementException:
            Size1 = "NA"

        # Find the Size2

        try:
            Size2_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-product-variants-container/div/app-fab-variant-size-selector/div/div[3]/div[2]/button')
            if Size2_element.is_enabled():
                Size2 = Size2_element.text.strip().replace('\n', ' ')
            else:
                Size2 = "NA"
        except NoSuchElementException:
            Size2 = "NA"

        # Find the Size3

        try:
            Size3_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-product-variants-container/div/app-fab-variant-size-selector/div/div[3]/div[3]/button')
            if Size3_element.is_enabled():
                Size3 = Size3_element.text.strip().replace('\n', ' ')
            else:
                Size3 = "NA"
        except NoSuchElementException:
            Size3 = "NA"

        # Find the Size4

        try:
            Size4_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-product-variants-container/div/app-fab-variant-size-selector/div/div[3]/div[4]/button')
            if Size4_element.is_enabled():
                Size4 = Size4_element.text.strip().replace('\n', ' ')
            else:
                Size4 = "NA"
        except NoSuchElementException:
            Size4 = "NA"

        # Find the Size5

        try:
            Size5_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-product-variants-container/div/app-fab-variant-size-selector/div/div[3]/div[6]/button')
            if Size5_element.is_enabled():
                Size5 = Size5_element.text.strip().replace('\n', ' ')
            else:
                Size5 = "NA"
        except NoSuchElementException:
            Size5 = "NA"

        # Find the Size6

        try:
            Size6_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-product-variants-container/div/app-fab-variant-size-selector/div/div[3]/div[7]/button')
            if Size6_element.is_enabled():
                Size6 = Size6_element.text.strip().replace('\n', ' ')
            else:
                Size6 = "NA"
        except NoSuchElementException:
            Size6 = "NA"



        
         

        
        
   
        
        # Find the Reviews
        try:
            # Reviews_element = driver.find_element(By.XPATH, '//*[@id="yotpo-bottomline-top-div"]/div/div[1]/div[1]/span/span[6]')
            # Reviews = Reviews_element.text.strip().replace('\n', ' ')
            # if Reviews =='0':
            Reviews = "NA"
        except NoSuchElementException:
            Reviews = "NA"


        try:
            Returntime_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/main/cx-page-layout/cx-page-slot[1]/app-fab-pincode-check/ul/li[3]/h4')
            Returntime = Returntime_element.text.strip().replace('\n', ' ')
        except NoSuchElementException:
            Returntime = "NA"

        try:
            Occasion_element = driver.find_element(By.XPATH, '//*[@id="flush-collapseOne"]/div/cx-product-attributes/div/div/table/tr[8]/td[3]/ul/li')
            Occasion = Occasion_element.text.strip().replace('\n', ' ')
        except NoSuchElementException:
            Occasion = "NA"

        try:
            Wear_Type_element = driver.find_element(By.XPATH, '/html/body/app-root/cx-storefront/div[4]/div/cx-page-slot/app-fab-bread-crumb/nav/a[3]')
            Wear_Type = Wear_Type_element.text.strip().replace('\n', ' ')
        except NoSuchElementException:
            Wear_Type = "NA"
       
    



        # Write Sno, link, and product name to the CSV file
        csv_writer.writerow([sno,'FabIndia','Men', absolute_url,product_type, product_name,product_code, product_price,color1,color2,color3,color4,Wear_Type,MaterialType,Reviews,Size1,Size2,Size3,Size4,Size5,Size6,CountryOfOrigin,Returntime,Occasion])
        
        driver.switch_to.window(driver.window_handles[-1])

        # Close the new tab
        driver.close()

        # Switch back to the original tab
        driver.switch_to.window(driver.window_handles[0])

        # Increment Sno
        sno += 1

        # Wait for 200 milliseconds before proceeding to the next tab
        time.sleep(0.2)
