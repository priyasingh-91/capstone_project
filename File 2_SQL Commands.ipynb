# %% [markdown]
# # <center> Capstone Project

# %% [markdown]
# ### Merge the webscrapped datasets extract from various webpages

# %%
# import pandas as pd

# # Read and uppercase column names for each CSV file
# df1 = pd.read_csv('BibaWomen_bottomwear.csv').rename(str.upper, axis='columns')
# df2 = pd.read_csv('BibaWomen_collection.csv').rename(str.upper, axis='columns')
# df3 = pd.read_csv('BibaWomen_dress.csv').rename(str.upper, axis='columns')
# df4 = pd.read_csv('BibaWomen_Kids.csv').rename(str.upper, axis='columns')
# df5 = pd.read_csv('FabIndia_Kid.csv').rename(str.upper, axis='columns')
# df6 = pd.read_csv('FabIndia_Men.csv').rename(str.upper, axis='columns')
# df7 = pd.read_csv('FabIndia_WoMen.csv').rename(str.upper, axis='columns')
# df8 = pd.read_csv('WforWomen_Topwear&dress.csv').rename(str.upper, axis='columns')

# # Change float columns to object type
# float_columns = ['PRICE']
# for df in [df1, df2, df3, df4, df5, df6, df7, df8]:
#     for col in float_columns:
#         if col in df.columns:
#             df[col] = df[col].astype(str)

# # Concatenate DataFrames
# merged_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8])

# # Save the merged DataFrame to a CSV file
# merged_df.to_csv('Data.csv', index=False)

# %%
data = pd.read_csv('Data.csv')
data.head()
# Out:
#    SNO BRANDNAME CATEGORY                                               LINK  \
# 0    1      BIBA    WoMen  https://www.biba.in/almond-beige-cotton-flax-r...
# 1    2      BIBA    WoMen  https://www.biba.in/navy-blue-cotton-straight-...
# 2    3      BIBA    WoMen  https://www.biba.in/black-cotton-pant/BOTTOMW1...
# 3    4      BIBA    WoMen  https://www.biba.in/ink-blue-viscose-blend-pal...
# 4    5      BIBA    WoMen  https://www.biba.in/off-white-viscose-flared-p...
#
#                       PRODUCTTYPE                            PRODUCTNAME  \
# 0        Bottom Type Regular Pant  ALMOND BEIGE COTTON FLAX REGULAR PANT
# 1            Bottom Type Palazzos      NAVY BLUE COTTON STRAIGHT PALAZZO
# 2        Bottom Type Regular Pant                      BLACK COTTON PANT
# 3  Bottom Pattern Detail Yarndyed        INK BLUE VISCOSE BLEND PALAZZOS
# 4             Bottom Type Palazzo       OFF WHITE VISCOSE FLARED PALAZZO
#
# ...

# %%
data.shape
# Out:
# (4083, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4083 entries, 0 to 4082
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNO              4083 non-null   int64
#  1   BRANDNAME        4083 non-null   object
#  2   CATEGORY         4083 non-null   object
#  3   LINK             4083 non-null   object
#  4   PRODUCTTYPE      3399 non-null   object
#  5   PRODUCTNAME      4060 non-null   object
#  6   PRODUCTCODE      3192 non-null   object
#  7   PRICE            3960 non-null   object
#  8   COLOR1           4060 non-null   object
#  9   COLOR2           690 non-null    object
#  10  COLOR3           364 non-null    object
#  11  COLOR4           164 non-null    object
#  12  WEARTYPE         2600 non-null   object
#  13  MATERIALTYPE     2859 non-null   object
#  14  REVIEWS          4083 non-null   int64
#  15  SIZE1            3422 non-null   object
# ...

# %%
# data['PRICE'] = data['PRICE'].str.extract(r'(\d+\.?\d*)')

data['PRICE'] = data['PRICE'].str.replace(',', '').str.extract(r'(\d+\.?\d*)')
data['PRICE'] = data['PRICE'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4083 entries, 0 to 4082
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNO              4083 non-null   int64
#  1   BRANDNAME        4083 non-null   object
#  2   CATEGORY         4083 non-null   object
#  3   LINK             4083 non-null   object
#  4   PRODUCTTYPE      3399 non-null   object
#  5   PRODUCTNAME      4060 non-null   object
#  6   PRODUCTCODE      3192 non-null   object
#  7   PRICE            3868 non-null   float64
#  8   COLOR1           4060 non-null   object
#  9   COLOR2           690 non-null    object
#  10  COLOR3           364 non-null    object
#  11  COLOR4           164 non-null    object
#  12  WEARTYPE         2600 non-null   object
#  13  MATERIALTYPE     2859 non-null   object
#  14  REVIEWS          4083 non-null   int64
#  15  SIZE1            3422 non-null   object
# ...

# %%
data['CATEGORY'].unique()
# Out:
# array(['WoMen', 'Kids', 'Men', 'Women'], dtype=object)

# %%
data['CATEGORY'] = data['CATEGORY'].replace('WoMen', 'Women')

# %%
data['BRANDNAME'].unique()
# Out:
# array(['BIBA', 'FabIndia', 'WforWomen'], dtype=object)

# %%
size_mapping = {'S': '32', 'M': '34', 'L': '36', 'XL': '38', 'XXL': '40'}

# Apply mapping to size columns
size_columns = ['SIZE1', 'SIZE2', 'SIZE3', 'SIZE4', 'SIZE5', 'SIZE6']
for col in size_columns:
    data[col] = data[col].map(size_mapping)

# %%
data['SIZE1'].unique()
# Out:
# array(['32', '34', '40', nan], dtype=object)

# %%
import pandas as pd
import numpy as np

# Assuming df is your DataFrame
df = data.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4083 entries, 0 to 4082
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNO              4083 non-null   int64
#  1   BRANDNAME        4083 non-null   object
#  2   CATEGORY         4083 non-null   object
#  3   LINK             4083 non-null   object
#  4   PRODUCTTYPE      3399 non-null   object
#  5   PRODUCTNAME      4060 non-null   object
#  6   PRODUCTCODE      3192 non-null   object
#  7   PRICE            3868 non-null   float64
#  8   COLOR1           4060 non-null   object
#  9   COLOR2           690 non-null    object
#  10  COLOR3           364 non-null    object
#  11  COLOR4           164 non-null    object
#  12  WEARTYPE         2600 non-null   object
#  13  MATERIALTYPE     2859 non-null   object
#  14  REVIEWS          4083 non-null   int64
#  15  SIZE1            1121 non-null   object
# ...

# %% [markdown]
# ## Phase2: SQL Commands -- Save the datasets in form of Table1, Table2 and Table3

# %%
# Extract specified columns
table1 = data[['SNO', 'BRANDNAME', 'CATEGORY', 'PRODUCTTYPE', 'PRODUCTNAME', 'PRODUCTCODE', 'PRICE']]

# Save the extracted table to a CSV file
table1.to_csv('Table1.csv', index=False)

# %%
# Extract specified columns
table2 = data[['SNO', 'COLOR1', 'COLOR2', 'COLOR3', 'COLOR4', 'WEARTYPE', 'MATERIALTYPE', 'REVIEWS','PRICE']]

# Save the extracted table to a CSV file
table2.to_csv('Table2.csv', index=False)

# %%
# Extract specified columns
table3 = data[['SNO', 'SIZE1', 'SIZE2', 'SIZE3', 'SIZE4', 'WEARTYPE', 'COUNTRYOFORIGIN', 'RETURNTIME', 'OCCASION']]

# Save the extracted table to a CSV file
table3.to_csv('Table3.csv', index=False)

# %% [markdown]
# ### TABLE 1

# %%
table1 = pd.read_csv('Table1.csv')
table1.head()
# Out:
#    SNO BRANDNAME CATEGORY                     PRODUCTTYPE  \
# 0    1      BIBA    Women        Bottom Type Regular Pant
# 1    2      BIBA    Women            Bottom Type Palazzos
# 2    3      BIBA    Women        Bottom Type Regular Pant
# 3    4      BIBA    Women  Bottom Pattern Detail Yarndyed
# 4    5      BIBA    Women             Bottom Type Palazzo
#
#                              PRODUCTNAME PRODUCTCODE  PRICE
# 0  ALMOND BEIGE COTTON FLAX REGULAR PANT         NaN  599.0
# 1      NAVY BLUE COTTON STRAIGHT PALAZZO         NaN  599.0
# 2                      BLACK COTTON PANT         NaN  599.0
# 3        INK BLUE VISCOSE BLEND PALAZZOS         NaN  599.0
# 4       OFF WHITE VISCOSE FLARED PALAZZO         NaN  999.0

# %%
table1.shape
# Out:
# (4083, 7)

# %%
table1.head()
# Out:
#    SNO BRANDNAME CATEGORY                     PRODUCTTYPE  \
# 0    1      BIBA    Women        Bottom Type Regular Pant
# 1    2      BIBA    Women            Bottom Type Palazzos
# 2    3      BIBA    Women        Bottom Type Regular Pant
# 3    4      BIBA    Women  Bottom Pattern Detail Yarndyed
# 4    5      BIBA    Women             Bottom Type Palazzo
#
#                              PRODUCTNAME PRODUCTCODE  PRICE
# 0  ALMOND BEIGE COTTON FLAX REGULAR PANT         NaN  599.0
# 1      NAVY BLUE COTTON STRAIGHT PALAZZO         NaN  599.0
# 2                      BLACK COTTON PANT         NaN  599.0
# 3        INK BLUE VISCOSE BLEND PALAZZOS         NaN  599.0
# 4       OFF WHITE VISCOSE FLARED PALAZZO         NaN  999.0

# %% [markdown]
# 1)	Write a query to Retrieve the Top 20  Most Expensive Products

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2)	Write a query Calculate the Total Price for Each Category:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3)	Write a query to Retrieve Products with a Price Range 2000 to 5000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4)	Write a query to Calculate the Average Price for Each Brand .

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5)   Write a query to find Products with Unique Brand-Category Combinations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### TABLE 2

# %%
table2 = pd.read_csv('Table2.csv')
table2.shape
# Out:
# (4083, 9)

# %%
table2.head()
# Out:
#    SNO        COLOR1    COLOR2 COLOR3 COLOR4 WEARTYPE MATERIALTYPE  REVIEWS  \
# 0    1  Almond Beige       NaN    NaN    NaN      NaN          NaN        0
# 1    2          Navy       NaN    NaN    NaN      NaN          NaN        0
# 2    3         Black       NaN    NaN    NaN      NaN          NaN        0
# 3    4  Almond Beige  Ink Blue    NaN    NaN      NaN          NaN        0
# 4    5      Offwhite       NaN    NaN    NaN      NaN          NaN        0
#
#    PRICE
# 0  599.0
# 1  599.0
# 2  599.0
# 3  599.0
# 4  999.0

# %% [markdown]
# 1)	Write a query Order Rows by Material Type in Ascending Order.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2)      Write a query to Calculate the Average Number of Reviews

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3)	Write a query to Retrieve the Top 30 Most Expensive Products by Weartype:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 4)	Write a query to Find Products with Similar Colors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5)   Write a query to Calculate the Total Price for Each Material Type.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### TABLE 3

# %%
table3 = pd.read_csv('Table3.csv')
table3.shape
# Out:
# (4083, 9)

# %%
table3.head()   # S:32, M:34, L:36, XL:38
# Out:
#    SNO  SIZE1  SIZE2  SIZE3  SIZE4 WEARTYPE COUNTRYOFORIGIN  \
# 0    1   32.0   34.0   36.0   38.0      NaN             NaN
# 1    2   32.0   34.0   36.0   38.0      NaN             NaN
# 2    3   32.0   34.0   36.0   38.0      NaN             NaN
# 3    4   32.0   34.0   36.0   38.0      NaN             NaN
# 4    5   32.0   34.0   36.0   38.0      NaN             NaN
#
#             RETURNTIME OCCASION
# 0  15 Days Easy Return  regular
# 1  15 Days Easy Return  regular
# 2  15 Days Easy Return  regular
# 3  15 Days Easy Return  regular
# 4  15 Days Easy Return  regular

# %% [markdown]
# 1)	Write a query to Order Rows by Return Time in Ascending Order.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2)	Write a query to find distinct country of origin.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3)	Write a query to Calculate the Average Return Time by Country of Origin.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4)	Write a query to Find Occasions with High Return Times.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5)   Write a query to Retrieve Products with Multiple Sizes (Size1, Size2, Size3, Size4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## JOIN QUERY  using table1,table2 and table3

# %% [markdown]
# Write a query  find Brandname, Category , Producttype ,ProductName  with a listed price greater than the average listed price in table 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write a query to list all Brandname, Category , Producttype ,ProductName   along with their corresponding color information from Table2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write a query to find the average reviews for each Producttype ,ProductName   using table 1 and table 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write a query  to find products with a Product name, material type that matches the most common material type in (use table1 and table 2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write a query  to find products with a Product name, material type that matches the most common material type in (use table1 and table 2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write a query  to find the average return time for each product type (use table1 and table 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Write a query to find Country of origin, return time ,occasion of each product type .
# (use table 1 and table 3)

# %% [markdown]
# ![image.png](attachment:image.png)
